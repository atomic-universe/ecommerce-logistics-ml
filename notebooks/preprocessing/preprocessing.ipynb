# %%
import numpy as np
import pandas as pd
import warnings
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### helping functions/ methods

# %%
def get_dataset(dataset:str)->str:
    try:
        return pd.read_csv(os.path.join('..','data','raw',f'{dataset}.csv'))
    except Exception as e:
        warnings.warn(f'"{dataset}" dataset not present.')
        return None

# %%
def check_is_unique(dataframe,column_names):
    '''
    print that the given columns is unique or not.
    parameters:
    dataframe: pandas dataframe
    column_name : name of the column which want to check.
    '''
    if  type(column_names) == str:
        print(f"'{column_names}' is a unique in table ? { dataframe[column_names].is_unique}")
        return; 
    else:
        for column_name in column_names:
            print(f"'{column_name}' is a unique in table ? { dataframe[column_name].is_unique}")

# %% [markdown]
# ### Load the datasets

# %%
# import the dataset
df_customers = get_dataset('customers')
df_order_items  = get_dataset('order_items')
df_geolocation = get_dataset('geolocation')
df_sellers = get_dataset('sellers')
df_orders = get_dataset('orders')
df_reviews = get_dataset('order_reviews')

# %% [markdown]
# #### understand the data

# %%
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB

# %%
df_customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
df_customers.duplicated(subset=['customer_id'], keep=False).sum()
# Out:
# np.int64(0)

# %%
df_customers['customer_id'].is_unique
# Out:
# True

# %%
df_customers.duplicated(subset=['customer_unique_id'], keep=False).sum()
# Out:
# np.int64(6342)

# %%
df_customers[df_customers.duplicated(subset=['customer_unique_id'], keep=False)]
# Out:
#                             customer_id                customer_unique_id  \
# 6      000419c5494106c306a97b5635748086  14843983d4a159080f6afe4b7f346e7c
# 8      00050bf6e01e69d5c0fd612f1bcfb69c  e3cf594a99e810f58af53ed4820f25e5
# 19     0010068a73b7c56da5758c3f9e5c7375  03dabd77cb0ed7a26fafe19e36b67742
# 29     00146ad30454993879adaa91c518f68c  5616f75d22507069b5383854a1d8c414
# 60     002b5342c72978cf0aba6aae1f5d5293  76e5f3bca2b1f5c510c41563c2ea31a4
# ...                                 ...                               ...
# 99359  ffc436ef9df6ede268ee1548a0dfbbba  89e3027de49c3012858cfeb7f5a34f59
# 99423  fff4fdd0de70a51d4e0f57a4c1c6bfae  7b6d07dac0a2c373d749142e920ae356
# 99428  fff7466a253c0e59499ea943462c10f9  1b6c7548a2a1f9037c1fd3ddfed95f33
# 99431  fff93c1da78dafaaa304ff032abc6205  d8dc373219d0f95053c8d65df85a7f1c
# 99439  ffffa3172527f765de70084a7e53aae8  48fd7dec70f2b104a1d5e8c5c639102b
#
#        customer_zip_code_prefix   customer_city customer_state
# 6                         24220         niteroi             RJ
# 8                         98700            ijui             RS
# 19                        63680         parambu             CE
# 29                        31060  belo horizonte             MG
# 60                        22775  rio de janeiro             RJ
# ...                         ...             ...            ...
# 99359                     24724     sao goncalo             RJ
# 99423                      9111     santo andre             SP
# 99428                     38301       ituiutaba             MG
# 99431                     14802      araraquara             SP
# 99439                     37130         alfenas             MG
#
# [6342 rows x 5 columns]

# %% [markdown]
# ### table2. order

# %%
df_orders.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1  00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2  000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-09-13 08:59:02  2017-09-13 09:45:35
# 1    delivered      2017-04-26 10:53:06  2017-04-26 11:05:13
# 2    delivered      2018-01-14 14:33:31  2018-01-14 14:48:30
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-09-19 18:34:16           2017-09-20 23:43:48
# 1          2017-05-04 14:35:00           2017-05-12 16:04:24
# 2          2018-01-16 12:36:48           2018-01-22 13:19:16
#
#   order_estimated_delivery_date
# 0                    2017-09-29
# 1                    2017-05-15
# 2                    2018-02-05

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB

# %%
check_is_unique(df_orders,'order_id')
check_is_unique(df_orders,'customer_id')
# Out:
# 'order_id' is a unique in table ? True
# 'customer_id' is a unique in table ? True

# %%
df_orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
df_orders = df_orders.dropna(axis=0)

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  str
#  1   customer_id                    96461 non-null  str
#  2   order_status                   96461 non-null  str
#  3   order_purchase_timestamp       96461 non-null  str
#  4   order_approved_at              96461 non-null  str
#  5   order_delivered_carrier_date   96461 non-null  str
#  6   order_delivered_customer_date  96461 non-null  str
#  7   order_estimated_delivery_date  96461 non-null  str
# dtypes: str(8)
# memory usage: 6.6 MB

# %%
df_orders = df_orders[df_orders['order_status']=='delivered']

# %%
#check duplicate records.
df_orders.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### table 3. order_items

# %%
df_order_items.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 2  2018-01-18 14:48:30  199.0          17.87

# %%
df_order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  str
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 6.0 MB

# %%
check_is_unique(df_order_items,'order_item_id')
check_is_unique(df_order_items,'order_id')
check_is_unique(df_order_items,'seller_id')
check_is_unique(df_order_items,'product_id')
# Out:
# 'order_item_id' is a unique in table ? False
# 'order_id' is a unique in table ? False
# 'seller_id' is a unique in table ? False
# 'product_id' is a unique in table ? False

# %%
df_order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_order_items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df_order_items.duplicated(subset=['order_item_id'],keep='first').sum()
# Out:
# np.int64(112629)

# %%
df_order_items.duplicated(subset=['order_id','order_item_id']).sum()
# Out:
# np.int64(0)

# %%
df_order_items['order_item_id'].nunique()
# Out:
# 21

# %%
df_order_items.groupby('order_id')['order_item_id'].count().sort_values(ascending=False)
# Out:
# order_id
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# fff1e3e76b816bfe8ef16678cc53c643     1
# fff2cdc825f9fc0ba3c04227cfa02303     1
# fff2e9e3aa8644e19710216b4ef53ab2     1
# fff3983dfa3c5a0d752d8d17baa406a0     1
# fffe41c64501cc87c801fd61db3f6244     1
# Name: order_item_id, Length: 98666, dtype: int64

# %%
df_order_items['product_id'].value_counts().count()
# Out:
# np.int64(32951)

# %% [markdown]
# ### table.4 geolocation

# %%
df_geolocation.head(3)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1001       -23.551427       -46.634074
# 1                         1001       -23.551337       -46.634027
# 2                         1001       -23.550642       -46.634410
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP

# %%
df_geolocation.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720154 entries, 0 to 720153
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  720154 non-null  int64
#  1   geolocation_lat              720154 non-null  float64
#  2   geolocation_lng              720154 non-null  float64
#  3   geolocation_city             720154 non-null  str
#  4   geolocation_state            720154 non-null  str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 27.5 MB

# %%
check_is_unique(df_geolocation,'geolocation_zip_code_prefix')
# Out:
# 'geolocation_zip_code_prefix' is a unique in table ? False

# %%
df_geolocation.duplicated(subset=['geolocation_zip_code_prefix'],keep='first').sum()
# Out:
# np.int64(701139)

# %% [markdown]
# #### So there is catch that 'geolocation_zip_code_prefix' have the duplicate entries so in order to join it with customer and seller we first take average of latitude and longitude of each zip code

# %%
df_unique_geolocation = df_geolocation.groupby('geolocation_zip_code_prefix').agg({'geolocation_lat':'mean','geolocation_lng':'mean'}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_unique_geolocation = df_geolocation.groupby('geolocation_zip_code_prefix').agg({'geolocation_lat':'mean','geolocation_lng':'mean'}).reset_index()
#
# NameError: name 'df_geolocation' is not defined

# %%
check_is_unique(df_unique_geolocation,'geolocation_zip_code_prefix')

# %%
df_unique_geolocation.info()

# %%
df_unique_geolocation[df_unique_geolocation['geolocation_lng']>100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_unique_geolocation[df_unique_geolocation['geolocation_lng']>100]
#
# NameError: name 'df_unique_geolocation' is not defined

# %%
df_geolocation[df_geolocation['geolocation_zip_code_prefix']==95130]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_geolocation[df_geolocation['geolocation_zip_code_prefix']==95130]
#
# NameError: name 'df_geolocation' is not defined

# %%
# Removing outliers

# only take zip code with comes under the brazil endpoint langitude and latitude.
#longitude
data =df_unique_geolocation[(df_unique_geolocation['geolocation_lng']>-34.79277) & (df_unique_geolocation['geolocation_lng']<-73.98444 )]
# Latitude
data = df_unique_geolocation[(df_unique_geolocation['geolocation_lat'] > -33.742222) & (df_unique_geolocation['geolocation_lat']<5.2722) ]

# remap to original data frame.
df_unique_geolocation =  data
plt.figure(figsize=(7,6))
plt.scatter(y = data['geolocation_lat'],x=data['geolocation_lng'])
plt.title('Brazil zip code wise latitude and longitude.')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 # Removing outliers
#       2
#       3 # only take zip code with comes under the brazil endpoint langitude and latitude.
#       4 #longitude
# ----> 5 data =df_unique_geolocation[(df_unique_geolocation['geolocation_lng']>-34.79277) & (df_unique_geolocation['geolocation_lng']<-73.98444 )]
#       6 # Latitude
#       7 data = df_unique_geolocation[(df_unique_geolocation['geolocation_lat'] > -33.742222) & (df_unique_geolocation['geolocation_lat']<5.2722) ]
#
# NameError: name 'df_unique_geolocation' is not defined

# %%
df_unique_geolocation.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_unique_geolocation.info()
#
# NameError: name 'df_unique_geolocation' is not defined

# %%
df_unique_geolocation.to_csv('unique_geolocation.csv',index=False)

# %% [markdown]
# ### table 5. Seller

# %%
df_sellers.head(3)
# Out:
#                           seller_id  seller_zip_code_prefix  seller_city  \
# 0  0015a82c2db000af6aaaf3ae2ecb0532                    9080  santo andre
# 1  001cca7ae9ae17fb1caed9dfb1094831                   29156    cariacica
# 2  001e6ad469a905060d959994f1b41e4f                   24754  sao goncalo
#
#   seller_state
# 0           SP
# 1           ES
# 2           RJ

# %%
# check information 
df_sellers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   str
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   str
#  3   seller_state            3095 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 96.8 KB

# %%
check_is_unique(df_sellers,['seller_id','seller_zip_code_prefix','seller_city','seller_state'])
# Out:
# 'seller_id' is a unique in table ? True
# 'seller_zip_code_prefix' is a unique in table ? False
# 'seller_city' is a unique in table ? False
# 'seller_state' is a unique in table ? False

# %%
# check duplicates

df_sellers.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Merging all dataframe

# %%
# join the customer and orders dataframe 
df_cust_join_order = pd.merge(left =df_customers,right=df_orders,on='customer_id',how='inner')
df_cust_join_order.head(3)
# Out:
#                         customer_id                customer_unique_id  \
# 0  00012a2ce6f8dcda20d059ce98491703  248ffe10d632bebe4f7267f1f44844c9
# 1  000161a058600d5901f007fab4c27140  b0015e09bb4b6e47c52844fab5fb6638
# 2  0001fd6190edaaf884bcaf3d49edf079  94b11d37cd61cb2994a194d11f89682b
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                      6273        osasco             SP
# 1                     35550   itapecerica             MG
# 2                     29830  nova venecia             ES
#
#                            order_id order_status order_purchase_timestamp  \
# 0  5f79b5b0931d63f1a42989eb65b9da6e    delivered      2017-11-14 16:08:26
# 1  a44895d095d7e0702b6a162fa2dbeced    delivered      2017-07-16 09:40:32
# 2  316a104623542e4d75189bb372bc5f8d    delivered      2017-02-28 11:06:43
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-11-14 16:35:32          2017-11-17 15:32:08
# 1  2017-07-16 09:55:12          2017-07-19 19:09:37
# 2  2017-02-28 11:15:20          2017-03-01 15:24:20
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2017-11-28 15:41:30                    2017-12-04
# 1           2017-07-25 18:57:33                    2017-08-04
# 2           2017-03-06 08:57:49                    2017-03-22

# %%
check_is_unique(df_cust_join_order,['customer_id','customer_unique_id'])
print(f'lenght of dataset {len(df_cust_join_order)}')
# Out:
# 'customer_id' is a unique in table ? True
# 'customer_unique_id' is a unique in table ? False
# lenght of dataset 96455

# %%
# now add the lattitude and longitude of each record of customer from geolocation ( 'unique_geolocation' ) dataframe.
df_custGeo_join_order  = pd.merge(left=df_cust_join_order, right = df_unique_geolocation, left_on = 'customer_zip_code_prefix',
         right_on = 'geolocation_zip_code_prefix', how = 'left')

# Important Column only
# imp_col = ['customer_id','customer_unique_id','order_id','order_status','order_purchase_timestamp','order_approved_at',
#  'order_delivered_carrier_date','order_delivered_customer_date','geolocation_lat','geolocation_lng']
# df_custGeo_join_order = df_custGeo_join_order[imp_col]

df_custGeo_join_order.rename(columns={'geolocation_lat':'customer_geolocation_lat','geolocation_lng':'customer_geolocation_lng','geolocation_zip_code_prefix':'customer_geolocation_zip_code_prefix'},inplace=True)
df_custGeo_join_order.head(3)
# Out:
#                         customer_id                customer_unique_id  \
# 0  00012a2ce6f8dcda20d059ce98491703  248ffe10d632bebe4f7267f1f44844c9
# 1  000161a058600d5901f007fab4c27140  b0015e09bb4b6e47c52844fab5fb6638
# 2  0001fd6190edaaf884bcaf3d49edf079  94b11d37cd61cb2994a194d11f89682b
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                      6273        osasco             SP
# 1                     35550   itapecerica             MG
# 2                     29830  nova venecia             ES
#
#                            order_id order_status order_purchase_timestamp  \
# 0  5f79b5b0931d63f1a42989eb65b9da6e    delivered      2017-11-14 16:08:26
# 1  a44895d095d7e0702b6a162fa2dbeced    delivered      2017-07-16 09:40:32
# 2  316a104623542e4d75189bb372bc5f8d    delivered      2017-02-28 11:06:43
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-11-14 16:35:32          2017-11-17 15:32:08
# 1  2017-07-16 09:55:12          2017-07-19 19:09:37
# 2  2017-02-28 11:15:20          2017-03-01 15:24:20
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-11-28 15:41:30                    2017-12-04
# 1           2017-07-25 18:57:33                    2017-08-04
# 2           2017-03-06 08:57:49                    2017-03-22
#
#    customer_geolocation_zip_code_prefix  customer_geolocation_lat  \
# 0                                6273.0                -23.499149
# 1                               35550.0                -20.469287
# 2                               29830.0                -18.705783
#
#    customer_geolocation_lng
# 0                -46.767812
# 1                -45.123459
# 2                -40.404736

# %%
# merge seller table with geolocation
 
df_seller_join_geolocation = pd.merge(left=df_sellers,right = df_unique_geolocation,
         left_on='seller_zip_code_prefix',right_on = 'geolocation_zip_code_prefix',how='left')
df_seller_join_geolocation.rename(columns={'geolocation_lat':'seller_geolocation_lat',
                                           'geolocation_lng':'seller_geolocation_lng',
                                            'geolocation_zip_code_prefix':'seller_geolocation_zip_code_prefix'  
                                          },inplace=True)
df_seller_join_geolocation.head(3)
# Out:
#                           seller_id  seller_zip_code_prefix  seller_city  \
# 0  0015a82c2db000af6aaaf3ae2ecb0532                    9080  santo andre
# 1  001cca7ae9ae17fb1caed9dfb1094831                   29156    cariacica
# 2  001e6ad469a905060d959994f1b41e4f                   24754  sao goncalo
#
#   seller_state  seller_geolocation_zip_code_prefix  seller_geolocation_lat  \
# 0           SP                              9080.0              -23.640101
# 1           ES                             29156.0              -20.279224
# 2           RJ                             24754.0              -22.872054
#
#    seller_geolocation_lng
# 0              -46.542293
# 1              -40.411514
# 2              -43.027422

# %%
# now merge the order_items dataframe

# %%
df_order_items.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 2  2018-01-18 14:48:30  199.0          17.87

# %%
check_is_unique(df_order_items,['order_id','seller_id'])
# Out:
# 'order_id' is a unique in table ? False
# 'seller_id' is a unique in table ? False

# %%
# in order items dataframe their are product id store and order_id .
# one order_id is equal to 1 user order
# in 1 order their may have multiple products.and for those product are in this table.
# so first check total how many orders are placed.

# the order_item_id may refere to
order_count = pd.DataFrame( df_order_items.groupby('order_id')['product_id'].count().sort_values(ascending=False))
print(f'their are total "{len(order_count)}" orders are placed')
print(f'and total product sells are "{len(df_order_items)}" ')
# Out:
# their are total "98666" orders are placed
# and total product sells are "112650"

# %%
# ok so problem is if user order more than 1 items each items have different sellers. they live in differnet location.
# then how we may not track and calculate distance?

# my approch for this problem is, first it is not possible to have one distance for each order so now instead of taking 
# any single aggrigation like min,max.
# we are going to used multiple features as follow Min Distance, Max Distance, Avg Distance and No. of sellers.

# %%
# merge order_items with seller_geo table

# df_orderItem_join_sellerGeo
df_orderItem_join_sellerGeo = pd.merge(left=df_order_items,right=df_seller_join_geolocation,on='seller_id',how='left')

# %%
df_orderItem_join_sellerGeo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   order_id                            112650 non-null  str
#  1   order_item_id                       112650 non-null  int64
#  2   product_id                          112650 non-null  str
#  3   seller_id                           112650 non-null  str
#  4   shipping_limit_date                 112650 non-null  str
#  5   price                               112650 non-null  float64
#  6   freight_value                       112650 non-null  float64
#  7   seller_zip_code_prefix              112650 non-null  int64
#  8   seller_city                         112650 non-null  str
#  9   seller_state                        112650 non-null  str
#  10  seller_geolocation_zip_code_prefix  112397 non-null  float64
#  11  seller_geolocation_lat              112397 non-null  float64
#  12  seller_geolocation_lng              112397 non-null  float64
# dtypes: float64(5), int64(2), str(6)
# memory usage: 11.2 MB

# %%
df_orderItem_join_sellerGeo.head(2)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
#
#    shipping_limit_date  price  freight_value  seller_zip_code_prefix  \
# 0  2017-09-19 09:45:35   58.9          13.29                   27277
# 1  2017-05-03 11:05:13  239.9          19.93                    3471
#
#      seller_city seller_state  seller_geolocation_zip_code_prefix  \
# 0  volta redonda           SP                             27277.0
# 1      sao paulo           SP                              3471.0
#
#    seller_geolocation_lat  seller_geolocation_lng
# 0              -22.497188              -44.127324
# 1              -23.565828              -46.519217

# %%
df_custGeo_join_order.head(2)
# Out:
#                         customer_id                customer_unique_id  \
# 0  00012a2ce6f8dcda20d059ce98491703  248ffe10d632bebe4f7267f1f44844c9
# 1  000161a058600d5901f007fab4c27140  b0015e09bb4b6e47c52844fab5fb6638
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                      6273        osasco             SP
# 1                     35550   itapecerica             MG
#
#                            order_id order_status order_purchase_timestamp  \
# 0  5f79b5b0931d63f1a42989eb65b9da6e    delivered      2017-11-14 16:08:26
# 1  a44895d095d7e0702b6a162fa2dbeced    delivered      2017-07-16 09:40:32
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-11-14 16:35:32          2017-11-17 15:32:08
# 1  2017-07-16 09:55:12          2017-07-19 19:09:37
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-11-28 15:41:30                    2017-12-04
# 1           2017-07-25 18:57:33                    2017-08-04
#
#    customer_geolocation_zip_code_prefix  customer_geolocation_lat  \
# 0                                6273.0                -23.499149
# 1                               35550.0                -20.469287
#
#    customer_geolocation_lng
# 0                -46.767812
# 1                -45.123459

# %%
# merge the orderItem_join_sellerGeo with customerGeo_join_order
df_master = pd.merge(left= df_orderItem_join_sellerGeo , right=df_custGeo_join_order, on='order_id',how='inner' )

# %%
df_master.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 110173 entries, 0 to 110172
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   order_id                              110173 non-null  str
#  1   order_item_id                         110173 non-null  int64
#  2   product_id                            110173 non-null  str
#  3   seller_id                             110173 non-null  str
#  4   shipping_limit_date                   110173 non-null  str
#  5   price                                 110173 non-null  float64
#  6   freight_value                         110173 non-null  float64
#  7   seller_zip_code_prefix                110173 non-null  int64
#  8   seller_city                           110173 non-null  str
#  9   seller_state                          110173 non-null  str
#  10  seller_geolocation_zip_code_prefix    109924 non-null  float64
#  11  seller_geolocation_lat                109924 non-null  float64
#  12  seller_geolocation_lng                109924 non-null  float64
#  13  customer_id                           110173 non-null  str
#  14  customer_unique_id                    110173 non-null  str
#  15  customer_zip_code_prefix              110173 non-null  int64
#  16  customer_city                         110173 non-null  str
#  17  customer_state                        110173 non-null  str
#  18  order_status                          110173 non-null  str
#  19  order_purchase_timestamp              110173 non-null  str
#  20  order_approved_at                     110173 non-null  str
#  21  order_delivered_carrier_date          110173 non-null  str
#  22  order_delivered_customer_date         110173 non-null  str
#  23  order_estimated_delivery_date         110173 non-null  str
#  24  customer_geolocation_zip_code_prefix  109877 non-null  float64
#  25  customer_geolocation_lat              109877 non-null  float64
#  26  customer_geolocation_lng              109877 non-null  float64
# dtypes: float64(8), int64(3), str(16)
# memory usage: 22.7 MB

# %%
check_is_unique(df_master,['order_id','order_item_id'])
# Out:
# 'order_id' is a unique in table ? False
# 'order_item_id' is a unique in table ? False

# %%
check_is_unique( df_order_items,'order_item_id')
# Out:
# 'order_item_id' is a unique in table ? False

# %%
print(len(df_master))
print(f" duplicateds : {df_master.duplicated(subset=['order_id', 'order_item_id']).sum()}")
# Out:
# 110173
#  duplicateds : 0

# %%
df_master.to_csv(os.path.join('..','data','processed','master_data.csv'),index=False)
